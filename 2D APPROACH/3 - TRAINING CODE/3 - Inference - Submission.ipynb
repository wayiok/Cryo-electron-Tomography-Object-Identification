# %% [markdown]
# # SUBMISSION
# In the trianing we built a model to find the xy coordinates of particles by using 2D object detection on sliced ​​images. This notebook focuses in finding  **the center of the circle**. But we need to find the coordinates of **the center of the sphere shaped particle**. Here we proposed to stack slices and consider points in the neighborhood of a given point to be points of the same sphere.

# %% [markdown]
# # Install and Import modules

# %%
# !pip download -d ./packages ultralytics
# !tar cfvz archive.tar.gz ./packages
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.67-py3-none-any.whl.metadata (35 kB)
# Collecting numpy>=1.23.0 (from ultralytics)
#   Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.0 MB/s eta 0:00:00
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Downloading matplotlib-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pillow>=7.1.2 (from ultralytics)
#   Downloading pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.0 MB/s eta 0:00:00
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.9 MB/s eta 0:00:00
# Collecting psutil (from ultralytics)
#   Downloading psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.5 MB/s eta 0:00:00
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->ultralytics)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->ultralytics)
#   Downloading fonttools-4.55.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.9/165.9 kB 11.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.3.0->ultralytics)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.3.0->ultralytics)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->ultralytics)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch>=1.8.0->ultralytics)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=1.8.0->ultralytics)
#   Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading ultralytics-8.3.67-py3-none-any.whl (913 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 32.8 MB/s eta 0:00:00
# Downloading matplotlib-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 91.2 MB/s eta 0:00:00
# Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 87.9 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 8.5 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 102.0 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 110.1 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 46.6 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 7.1 MB/s eta 0:00:00
# Downloading scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 15.0 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 27.3 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.7 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.8 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 105.6 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.9 MB/s eta 0:00:00
# Downloading torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 63.7 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 29.5 MB/s eta 0:00:00
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 19.0 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 17.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.2/326.2 kB 31.7 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.55.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 113.8 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 8.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.6 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.7 MB/s eta 0:00:00
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 12.9 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 24.8 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 41.5 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 33.8 MB/s eta 0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 14.7 MB/s eta 0:00:00
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 20.5 MB/s eta 0:00:00
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 14.5 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.7 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 44.6 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Saved ./packages/ultralytics-8.3.67-py3-none-any.whl
# Saved ./packages/matplotlib-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl
# Saved ./packages/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/requests-2.32.3-py3-none-any.whl
# Saved ./packages/scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/seaborn-0.13.2-py3-none-any.whl
# Saved ./packages/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl
# Saved ./packages/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Saved ./packages/sympy-1.13.1-py3-none-any.whl
# Saved ./packages/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl
# Saved ./packages/tqdm-4.67.1-py3-none-any.whl
# Saved ./packages/ultralytics_thop-2.0.14-py3-none-any.whl
# Saved ./packages/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/py_cpuinfo-9.0.0-py3-none-any.whl
# Saved ./packages/certifi-2024.12.14-py3-none-any.whl
# Saved ./packages/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/cycler-0.12.1-py3-none-any.whl
# Saved ./packages/fonttools-4.55.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/idna-3.10-py3-none-any.whl
# Saved ./packages/kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/packaging-24.2-py3-none-any.whl
# Saved ./packages/pyparsing-3.2.1-py3-none-any.whl
# Saved ./packages/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# Saved ./packages/pytz-2024.2-py2.py3-none-any.whl
# Saved ./packages/typing_extensions-4.12.2-py3-none-any.whl
# Saved ./packages/tzdata-2025.1-py2.py3-none-any.whl
# Saved ./packages/urllib3-2.3.0-py3-none-any.whl
# Saved ./packages/filelock-3.17.0-py3-none-any.whl
# Saved ./packages/fsspec-2024.12.0-py3-none-any.whl
# Saved ./packages/jinja2-3.1.5-py3-none-any.whl
# Saved ./packages/networkx-3.4.2-py3-none-any.whl
# Saved ./packages/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./packages/mpmath-1.3.0-py3-none-any.whl
# Saved ./packages/six-1.17.0-py2.py3-none-any.whl
# Successfully downloaded ultralytics matplotlib numpy opencv-python pandas pillow pyyaml requests scipy seaborn torch nvidia-cublas-cu12 nvidia-cuda-cupti-cu12 nvidia-cuda-nvrtc-cu12 nvidia-cuda-runtime-cu12 nvidia-cudnn-cu12 nvidia-cufft-cu12 nvidia-curand-cu12 nvidia-cusolver-cu12 nvidia-cusparse-cu12 nvidia-nccl-cu12 nvidia-nvjitlink-cu12 nvidia-nvtx-cu12 sympy triton torchvision tqdm ultralytics-thop psutil py-cpuinfo certifi charset-normalizer contourpy cycler fonttools idna kiwisolver packaging pyparsing python-dateutil pytz typing-extensions tzdata urllib3 filelock fsspec jinja2 networkx MarkupSafe mpmath six
# ./packages/
# ./packages/sympy-1.13.1-py3-none-any.whl
# ./packages/py_cpuinfo-9.0.0-py3-none-any.whl
# ./packages/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/cycler-0.12.1-py3-none-any.whl
# ./packages/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl
# ./packages/seaborn-0.13.2-py3-none-any.whl
# ./packages/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl
# ./packages/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/typing_extensions-4.12.2-py3-none-any.whl
# ./packages/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl
# ./packages/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/pytz-2024.2-py2.py3-none-any.whl
# ./packages/networkx-3.4.2-py3-none-any.whl
# ./packages/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# ./packages/six-1.17.0-py2.py3-none-any.whl
# ./packages/requests-2.32.3-py3-none-any.whl
# ./packages/torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl
# ./packages/matplotlib-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl
# ./packages/packaging-24.2-py3-none-any.whl
# ./packages/pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl
# ./packages/tzdata-2025.1-py2.py3-none-any.whl
# ./packages/kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/urllib3-2.3.0-py3-none-any.whl
# ./packages/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl
# ./packages/pyparsing-3.2.1-py3-none-any.whl
# ./packages/tqdm-4.67.1-py3-none-any.whl
# ./packages/fsspec-2024.12.0-py3-none-any.whl
# ./packages/certifi-2024.12.14-py3-none-any.whl
# ./packages/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl
# ./packages/ultralytics-8.3.67-py3-none-any.whl
# ./packages/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/filelock-3.17.0-py3-none-any.whl
# ./packages/mpmath-1.3.0-py3-none-any.whl
# ./packages/idna-3.10-py3-none-any.whl
# ./packages/ultralytics_thop-2.0.14-py3-none-any.whl
# ./packages/fonttools-4.55.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl
# ./packages/jinja2-3.1.5-py3-none-any.whl
# ./packages/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl

# %%
#We use the path of our google drive dataset folder

from google.colab import drive
drive.mount('/content/gdrive')
dataFolder = "gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/1 - SOURCE DATA/"
# Out:
# Mounted at /content/gdrive

# %%
# !tar xfvz 'gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/3 - TRAINING CODE/LIBRARIES/archive.tar.gz'
# !pip install --no-index --find-links=./packages ultralytics
# !rm -rf ./packages
# Out:
# ./packages/
# ./packages/numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/seaborn-0.13.2-py3-none-any.whl
# ./packages/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl
# ./packages/typing_extensions-4.12.2-py3-none-any.whl
# ./packages/psutil-6.1.1-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/mpmath-1.3.0-py3-none-any.whl
# ./packages/py_cpuinfo-9.0.0-py3-none-any.whl
# ./packages/torchvision-0.20.1-cp311-cp311-manylinux1_x86_64.whl
# ./packages/torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl
# ./packages/certifi-2024.12.14-py3-none-any.whl
# ./packages/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl
# ./packages/pytz-2024.2-py2.py3-none-any.whl
# ./packages/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/pyparsing-3.2.1-py3-none-any.whl
# ./packages/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/six-1.17.0-py2.py3-none-any.whl
# ./packages/opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/fsspec-2024.12.0-py3-none-any.whl
# ./packages/idna-3.10-py3-none-any.whl
# ./packages/scipy-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/matplotlib-3.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/packaging-24.2-py3-none-any.whl
# ./packages/ultralytics_thop-2.0.14-py3-none-any.whl
# ./packages/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl
# ./packages/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/tqdm-4.67.1-py3-none-any.whl
# ./packages/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl
# ./packages/pillow-11.1.0-cp311-cp311-manylinux_2_28_x86_64.whl
# ./packages/charset_normalizer-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/kiwisolver-1.4.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/urllib3-2.3.0-py3-none-any.whl
# ./packages/python_dateutil-2.9.0.post0-py2.py3-none-any.whl
# ./packages/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/filelock-3.16.1-py3-none-any.whl
# ./packages/triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/sympy-1.13.1-py3-none-any.whl
# ./packages/ultralytics-8.3.65-py3-none-any.whl
# ./packages/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl
# ./packages/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/fonttools-4.55.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl
# ./packages/cycler-0.12.1-py3-none-any.whl
# ./packages/requests-2.32.3-py3-none-any.whl
# ./packages/tzdata-2024.2-py2.py3-none-any.whl
# ./packages/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl
# ./packages/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# ./packages/contourpy-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# ./packages/networkx-3.4.2-py3-none-any.whl
# ./packages/jinja2-3.1.5-py3-none-any.whl
# ./packages/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
# Looking in links: ./packages
# Processing ./packages/ultralytics-8.3.67-py3-none-any.whl
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Processing ./packages/ultralytics_thop-2.0.14-py3-none-any.whl (from ultralytics)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.67 ultralytics-thop-2.0.14

# %%
# !pip install '/content/gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/1 - SOURCE DATA/1 - ORIGINAL DATASET/wheel_file/asciitree-0.3.3/asciitree-0.3.3'
# Out:
# Processing ./gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/1 - SOURCE DATA/1 - ORIGINAL DATASET/wheel_file/asciitree-0.3.3/asciitree-0.3.3
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: asciitree
#   Building wheel for asciitree (setup.py) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=46284ee996fb0677baaaca8f56edd751679f881c1ca12e58e2bfb0ae85fb26d7
#   Stored in directory: /root/.cache/pip/wheels/ad/66/a0/63b9951f2656f88f9459397bd81456aba0095aa26d17f8f8eb
# Successfully built asciitree
# Installing collected packages: asciitree
# Successfully installed asciitree-0.3.3

# %%
# !pip install --no-index --find-links='/content/gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/1 - SOURCE DATA/1 - ORIGINAL DATASET/wheel_file' zarr
# Out:
# Looking in links: /content/gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/1 - SOURCE DATA/1 - ORIGINAL DATASET/wheel_file
# Processing ./gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/1 - SOURCE DATA/1 - ORIGINAL DATASET/wheel_file/zarr-2.18.3-py3-none-any.whl
# Requirement already satisfied: asciitree in /usr/local/lib/python3.11/dist-packages (from zarr) (0.3.3)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from zarr) (1.26.4)
# INFO: pip is looking at multiple versions of zarr to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement numcodecs>=0.10.0 (from zarr) (from versions: none)
# ERROR: No matching distribution found for numcodecs>=0.10.0

# %%
# !pip install zarr
# Out:
# Collecting zarr
#   Downloading zarr-3.0.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting donfig>=0.8 (from zarr)
#   Downloading donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Collecting numcodecs>=0.14 (from numcodecs[crc32c]>=0.14->zarr)
#   Downloading numcodecs-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from zarr) (1.26.4)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.11/dist-packages (from zarr) (24.2)
# Requirement already satisfied: typing-extensions>=4.9 in /usr/local/lib/python3.11/dist-packages (from zarr) (4.12.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from donfig>=0.8->zarr) (6.0.2)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from numcodecs>=0.14->numcodecs[crc32c]>=0.14->zarr) (1.2.15)
# Collecting crc32c>=2.7 (from numcodecs[crc32c]>=0.14->zarr)
#   Downloading crc32c-2.7.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->numcodecs>=0.14->numcodecs[crc32c]>=0.14->zarr) (1.17.2)
# Downloading zarr-3.0.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.4/181.4 kB 14.3 MB/s eta 0:00:00
# Downloading donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Downloading numcodecs-0.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 65.7 MB/s eta 0:00:00
# Downloading crc32c-2.7.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: donfig, crc32c, numcodecs, zarr
# Successfully installed crc32c-2.7.1 donfig-0.8.1.post1 numcodecs-0.15.0 zarr-3.0.1

# %%
import zarr
from ultralytics import YOLO
from tqdm import tqdm
import glob, os
import torch
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# We use a recursive function in this notebook, and we change the settings to explore the graph deep enough.

# %%
import sys
sys.setrecursionlimit(10000)

# %%
import warnings
warnings.simplefilter('ignore')
np.warnings = warnings

# %% [markdown]
# # Prepare trained YOLO model

# %%
model = YOLO("/content/gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/3 - TRAINING CODE/MODELS/runs/detect/train/weights/best.pt")
dataFolder = "/content/gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/1 - SOURCE DATA/1 - ORIGINAL DATASET/"

# %%
runs = sorted(glob.glob(f'{dataFolder}test/static/ExperimentRuns/*'))
runs = [os.path.basename(x) for x in runs]
runs[:5]
# Out:
# ['TS_5_4', 'TS_69_2', 'TS_6_4']

# %%
#Information about labels

# %%
particle_names = ['apo-ferritin', 'beta-amylase', 'beta-galactosidase', 'ribosome', 'thyroglobulin', 'virus-like-particle']

# %%
p2i_dict = {
        'apo-ferritin': 0,
        'beta-amylase': 1,
        'beta-galactosidase': 2,
        'ribosome': 3,
        'thyroglobulin': 4,
        'virus-like-particle': 5
    }

i2p = {v:k for k, v in p2i_dict.items()}

# %%
particle_radius = {
        'apo-ferritin': 60,
        'beta-amylase': 65,
        'beta-galactosidase': 90,
        'ribosome': 150,
        'thyroglobulin': 130,
        'virus-like-particle': 135,
    }

# %% [markdown]
# # define Main process class
# There are many variables and functions going back and forth. We can easily manage variables by defining classes.

# %%
class PredAggForYOLO:
    def __init__(self, first_conf=0.2, final_conf=0.3, conf_coef=0.75):
        self.first_conf = first_conf # threshold of confidence yolo
        self.final_conf = final_conf # final threshold score (not be used in version 14)
        self.conf_coef = conf_coef # if found many points, give bonus
        self.particle_confs = [0.5, 0.0, 0.2, 0.5, 0.2, 0.5] # be strict to easy labels

    def convert_to_8bit(self, x):
        lower, upper = np.percentile(x, (0.5, 99.5))
        x = np.clip(x, lower, upper)
        x = (x - x.min()) / (x.max() - x.min() + 1e-12) * 255
        return x.round().astype("uint8")

    # depth first search.
    # aggregate the coordinates and confidence scores of connected graphs.
    def dfs(self, v):
        self.passed[v] = True
        self.conf_sum += self.pdf.iloc[v].confidence
        self.cx += self.pdf.iloc[v].x
        self.cy += self.pdf.iloc[v].y
        self.cz += self.pdf.iloc[v].z
        self.nv += 1
        for next_v in self.adjacency_list[v]:
            if (self.passed[next_v]): continue
            self.dfs(next_v)

    # main routine.
    def make_predict_yolo(self, r, model):
        vol = zarr.open(f'{dataFolder}test/static/ExperimentRuns/{r}/VoxelSpacing10.000/denoised.zarr', mode='r')
        vol = vol['0']
        vol2 = self.convert_to_8bit(vol)
        n_imgs = vol2.shape[0]

        df = pd.DataFrame()

        pts = []
        confs = []
        xs = []
        ys = []
        zs = []

        for i in range(n_imgs):
            # Unfortunately the image size needs to be a multiple of 32.
            tmp_img = np.zeros((630, 630))
            tmp_img[:] = vol2[i]

            inp_arr = np.stack([tmp_img]*3,axis=-1)
            inp_arr = cv2.resize(inp_arr, (640,640))
            res = model.predict(inp_arr, save=False, imgsz=640, conf=self.first_conf, device="0", batch=1, verbose=False)
            for j, result in enumerate(res):
                boxes = result.boxes # Boxes object for bounding box outputs
                for k in range(len(boxes.cls)):
                    ptype = i2p[boxes.cls.cpu().numpy()[k]] # particle type
                    conf = boxes.conf.cpu().numpy()[k] # confidence score
                    # YOLO can infer (start_x, end_x, start_y, end_y)
                    xc = (boxes.xyxy[k,0] + boxes.xyxy[k,2]) / 2.0 * 10 * (63/64)
                    yc = (boxes.xyxy[k,1] + boxes.xyxy[k,3]) / 2.0 * 10 * (63/64)
                    zc = i * 10 + 5

                    pts.append(ptype)
                    confs.append(conf)
                    xs.append(xc.cpu().numpy())
                    ys.append(yc.cpu().numpy())
                    zs.append(zc)

        df['particle_type'] = pts
        df['confidence'] = confs
        df['x'] = xs
        df['y'] = ys
        df['z'] = zs

        # df includes overall canditate of CIRCLE.
        df = df.sort_values(['particle_type', 'z'], ascending=[True, True])

        agg_df = []

        # infer center of sphere each particle types
        for pidx, p in enumerate(particle_names):
            if p == 'beta-amylase':
                continue
            pdf = df[df['particle_type']==p].reset_index(drop=True)
            self.pdf = pdf
            p_rad = particle_radius[p]

            # The distance between the x and y coordinates of adjacent slices is expected to be very small.
            xy_tol = p_rad / 16.0
            xy_tol_p2 = xy_tol ** 2

            # define the graph
            self.adjacency_list = [[] for _ in range(len(pdf))]
            # which already passed in dfs
            self.passed = [False for _ in range(len(pdf))]

            # Connect two points when they are close enough
            for i in range(len(pdf)):
                x1 = pdf['x'].iloc[i]
                y1 = pdf['y'].iloc[i]
                z1 = pdf['z'].iloc[i]
                for j in range(i+1, len(pdf), 1):
                    x2 = pdf['x'].iloc[j]
                    y2 = pdf['y'].iloc[j]
                    z2 = pdf['z'].iloc[j]
                    # Can be pruned. thanks to min fuka (@minfuka)
                    if abs(z1-z2)>20:
                        break

                    dist_p2 = (x1-x2)**2 + (y1-y2)**2
                    if dist_p2<xy_tol_p2 and dist_p2+(z1-z2)**2 < p_rad**2 and abs(z1-z2)<=20:
                        self.adjacency_list[i].append(j)
                        self.adjacency_list[j].append(i)

            rdf = pd.DataFrame()
            cxs = []
            cys = []
            czs = []

            # Perform DFS on all points and find the center of the sphere from the average of the coordinates
            for i in range(len(pdf)):
                self.conf_sum = 0
                self.nv = 0
                self.cx = 0
                self.cy = 0
                self.cz = 0
                if not self.passed[i]:
                    self.dfs(i)

                # Different confidence for different particle types
                if self.nv>=2 and self.conf_sum / (self.nv**self.conf_coef) > self.particle_confs[pidx]:
                    cxs.append(self.cx / self.nv)
                    cys.append(self.cy / self.nv)
                    czs.append(self.cz / self.nv)

            rdf['experiment'] = [r] * len(cxs)
            rdf['particle_type'] = [p] * len(cys)
            rdf['x'] = cxs
            rdf['y'] = cys
            rdf['z'] = czs

            agg_df.append(rdf)


        return pd.concat(agg_df, axis=0)

# %%
# instance main class
agent = PredAggForYOLO(first_conf=0.15, final_conf=0.2, conf_coef=0.5) # final_conf is not used after version 14

# %%
subs = []

# %%
import time

# %% [markdown]
# # main loop of inference

# %%
# %%time
tick = time.time()
for r in tqdm(runs, total=len(runs)):
    df = agent.make_predict_yolo(r, model)
    subs.append(df)
tock = time.time()
# Out:
# 100%|██████████| 3/3 [01:22<00:00, 27.56s/it]
# CPU times: user 43.4 s, sys: 6.86 s, total: 50.2 s
# Wall time: 1min 22s

# %%
print(f'estimated predict time is {(tock-tick)/3*500:.4f} seconds')
# Out:
# estimated predict time is 13779.1699 seconds

# %%
submission = pd.concat(subs).reset_index(drop=True)
submission.insert(0, 'id', range(len(submission)))

# %%
submission.to_csv("/content/gdrive/My Drive/MLDM - Deep Learning/CRYOET PROJECT - DEEP LEARNING/2D U-NET APPROACH/3 - TRAINING CODE/SUBMISSIONS/submission.csv", index=False)
submission.head()
# Out:
#    id experiment particle_type            x            y      z
# 0   0     TS_5_4  apo-ferritin  5875.813407  5129.741769   75.0
# 1   1     TS_5_4  apo-ferritin  5746.001831  5108.471313   90.0
# 2   2     TS_5_4  apo-ferritin  5465.139893  1517.812134  100.0
# 3   3     TS_5_4  apo-ferritin  5711.620361  4995.938232  110.0
# 4   4     TS_5_4  apo-ferritin  5295.965698  4168.894897  150.0

# %%
# prompt: create a dataframe that has precisio and recall of each particle tyoe in each experiment

import pandas as pd

# Assuming 'submission' DataFrame from the provided code is available

# Create a dictionary to store precision and recall for each particle type in each experiment
results = {}

# Iterate through unique experiments in the submission
for experiment in submission['experiment'].unique():
  results[experiment] = {}
  # Iterate through unique particle types
  for particle_type in submission['particle_type'].unique():
    # Filter data for current experiment and particle type
    experiment_data = submission[(submission['experiment'] == experiment) & (submission['particle_type'] == particle_type)]

    # Calculate precision and recall (replace with your actual calculation logic)
    # For example:
    # precision = len(experiment_data) / (total number of predicted instances for the particle type in the experiment)
    # recall = len(experiment_data) / (total number of ground truth instances for the particle type in the experiment)
    # Note: Replace the placeholders with your actual metrics.
    precision = 0.8  # Placeholder value
    recall = 0.7     # Placeholder value

    results[experiment][particle_type] = {'precision': precision, 'recall': recall}


# Create a DataFrame from the results dictionary
data = []
for experiment, particle_results in results.items():
  for particle_type, metrics in particle_results.items():
    data.append([experiment, particle_type, metrics['precision'], metrics['recall']])

df_results = pd.DataFrame(data, columns=['experiment', 'particle_type', 'precision', 'recall'])

# Display the DataFrame
df_results
# Out:
#    experiment        particle_type  precision  recall
# 0      TS_5_4         apo-ferritin        0.8     0.7
# 1      TS_5_4   beta-galactosidase        0.8     0.7
# 2      TS_5_4             ribosome        0.8     0.7
# 3      TS_5_4        thyroglobulin        0.8     0.7
# 4      TS_5_4  virus-like-particle        0.8     0.7
# 5     TS_69_2         apo-ferritin        0.8     0.7
# 6     TS_69_2   beta-galactosidase        0.8     0.7
# 7     TS_69_2             ribosome        0.8     0.7
# 8     TS_69_2        thyroglobulin        0.8     0.7
# 9     TS_69_2  virus-like-particle        0.8     0.7
# 10     TS_6_4         apo-ferritin        0.8     0.7
# 11     TS_6_4   beta-galactosidase        0.8     0.7
# 12     TS_6_4             ribosome        0.8     0.7
# 13     TS_6_4        thyroglobulin        0.8     0.7
# 14     TS_6_4  virus-like-particle        0.8     0.7

# %% [markdown]
# In the end we have seen how to use YOLO for 2D object detection and DFS to find the center of a sphere in space.
#
# It takes about **10 hours** from submission to scoring. This may be an area that needs improvement.
